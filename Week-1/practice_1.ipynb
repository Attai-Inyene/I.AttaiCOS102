# %%
num = 100
print(num)
print("Data Type of variable num is", type(num))

#float number
fnum = 34.45
print(num)
print("Data Type of variable fnum is", type(fnum))

#complex number
cnum = 3 + 4j
print(cnum)
print("Data type of variable", type(cnum))
